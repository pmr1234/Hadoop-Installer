# %% [markdown]
# # Experiment 9: Exploratory Data Analysis (EDA) and Feature Analysis
# **Aim:** To perform Exploratory Data Analysis (EDA) on a dataset using Pandas and Seaborn to understand relationships, distributions, and feature logic.

# %% [markdown]
# ### Step 1 & 2: Import Libraries and Load Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

df['species'] = iris.target
df['species'] = df['species'].map({
    0: 'Setosa',
    1: 'Versicolor',
    2: 'Virginica'
})

# %% [markdown]
# ### Step 3: Dataset Information

# %%
df.head()

# %%
df.info()

# %% [markdown]
# ### Step 4 & 5: Statistical Summary & Check Missing Values

# %%
df.describe()

# %%
df.isnull().sum()

# %% [markdown]
# ### Step 6: Univariate Analysis (Histogram)

# %%
plt.figure(figsize=(6,4))
df['sepal length (cm)'].hist(bins=20)
plt.title("Sepal Length Distribution")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Step 7: Univariate Analysis (Box Plot)

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df['petal length (cm)'])
plt.title("Petal Length Box Plot")
plt.show()

# %% [markdown]
# ### Step 8: Multivariate Analysis (Pair Plot)

# %%
sns.pairplot(df, hue='species')
plt.show()

# %% [markdown]
# ### Step 9: Feature Analysis (Correlation Heatmap)

# %%
plt.figure(figsize=(8,6))
sns.heatmap(
    df.drop('species', axis=1).corr(),
    annot=True,
    cmap='coolwarm'
)
plt.title("Correlation Heatmap")
plt.show()
